# %%
import pandas as pd

# %%
merged = pd.read_parquet('httparchive_data_raw/nel_data_2018_10.parquet')
merged
# Out:
#      requestId  firstReq    type   ext  \
# 0   2138734078      True    html
# 1   2138734102     False  script    js
# 2   2138734094     False  script    js
# 3   2138734100     False  script    js
# 4   2138734083     False  script    js
# ..         ...       ...     ...   ...
# 86  2789307095     False   image   php
# 87  2142863250     False  script  json
# 88  2151533234     False    html
# 89  2033405385      True    html
# 90  2033405392     False    html
#
#                                                   url url_etld  status  \
# 0                      https://classifieds.seloc.org/      org     200
# 1   https://classifieds.seloc.org/wp-content/theme...      org     200
# 2   https://classifieds.seloc.org/wp-content/theme...      org     200
# 3   https://classifieds.seloc.org/wp-content/theme...      org     200
# 4   https://classifieds.seloc.org/wp-includes/js/j...      org     200
# ..                                                ...      ...     ...
# ...

# %%
desktop_1 = pd.read_parquet('httparchive_data_raw/2018_10_01_desktop.parquet')
# desktop_1.drop_duplicates(['url'])
desktop_1
# Out:
#     requestId  firstReq    type ext  \
# 0  2564905503     False  script
# 1  2598825698      True    html
# 2  2666332269      True    html
# 3  2666332283     False    html
#
#                                                  url url_etld  status  \
# 0         http://cpqa.catchpoint.com/jp/191/v3.1.5/M      com     200
# 1                             https://www2.bing.com/      com     200
# 2                          https://scotthelme.co.uk/    co.uk     200
# 3  https://scotthelme.co.uk/security-and-convenie...    co.uk     200
#
#    total_crawled_resources  total_crawled_domains nel_max_age  \
# 0                 87572479                1177473     2592000
# 1                 87572479                1177473      604800
# 2                 87572479                1177473    10886400
# 3                 87572479                1177473    10886400
#
#   nel_failure_fraction nel_success_fraction nel_include_subdomains  \
# ...

# %%
desktop_2 = pd.read_parquet('httparchive_data_raw/2018_10_15_desktop.parquet')
# desktop_2.drop_duplicates(['url'])
desktop_2
# Out:
#      requestId  firstReq    type   ext  \
# 0   2697438644     False  script
# 1   2756586562     False    html
# 2   2756865876      True    html
# 3   2770687505     False    html
# 4   2711318255     False    html
# 5   2770687348      True    html
# 6   2791293720     False    html
# 7   2731241330      True    html
# 8   2789307056      True    html
# 9   2799279801      True    html
# 10  2799279820     False    html
# 11  2789307095     False   image   php
# 12  2789307119     False  script  json
#
#                                                   url url_etld  status  \
# 0          http://cpqa.catchpoint.com/jp/191/v3.1.5/M      com     200
# 1                   https://www.bing.com/?form=MO0035      com     200
# 2                https://insertmedia.bing.office.net/      net     200
# 3                   https://www.bing.com/?FORM=UNKSBD      com     200
# 4      https://www.bing.com/search?q=it-n&form=MSDTR1      com     200
# ...

# %%
mobile_1 = pd.read_parquet('httparchive_data_raw/2018_10_01_mobile.parquet')
# mobile_1.drop_duplicates(['url'])
mobile_1
# Out:
#     requestId  firstReq    type ext  \
# 0  1942450263     False  script
# 1  2033405392     False    html
# 2  2033405385      True    html
#
#                                                  url url_etld  status  \
# 0         http://cpqa.catchpoint.com/jp/191/v3.1.5/M      com     200
# 1  https://scotthelme.co.uk/security-and-convenie...    co.uk     200
# 2                          https://scotthelme.co.uk/    co.uk     200
#
#    total_crawled_resources  total_crawled_domains nel_max_age  \
# 0                 78069858                1171968     2592000
# 1                 78069858                1171968    10886400
# 2                 78069858                1171968    10886400
#
#   nel_failure_fraction nel_success_fraction nel_include_subdomains  \
# 0                  1.0                    0                   true
# 1                 None                 None                   None
# 2                 None                 None                   None
#
# ...

# %%
mobile_2 = pd.read_parquet('httparchive_data_raw/2018_10_15_mobile.parquet')
# mobile_2.drop_duplicates(['url'])
mobile_2
# Out:
#      requestId  firstReq    type    ext  \
# 0   2061855568     False  script
# 1   2142863160      True    html
# 2   2142863227     False   image    php
# 3   2142863250     False  script   json
# 4   2138734078      True    html
# ..         ...       ...     ...    ...
# 77  2159394297     False   image   webp
# 78  2159394305     False    font  woff2
# 79  2159394309     False    font  woff2
# 80  2151533218      True    html
# 81  2151533234     False    html
#
#                                                   url url_etld  status  \
# 0          http://cpqa.catchpoint.com/jp/191/v3.1.5/M      com     200
# 1                            https://www.gtopala.com/      com     200
# 2   https://www.gtopala.com/matomo/piwik/piwik.php...      com     200
# 3               https://www.gtopala.com/manifest.json      com     200
# 4                      https://classifieds.seloc.org/      org     200
# ..                                                ...      ...     ...
# ...

# %%
fragmented_all = pd.concat([desktop_2, desktop_1, mobile_2, mobile_1]).drop_duplicates(['url'])
fragmented_all
# Out:
#      requestId  firstReq    type    ext  \
# 0   2697438644     False  script
# 1   2756586562     False    html
# 2   2756865876      True    html
# 3   2770687505     False    html
# 4   2711318255     False    html
# ..         ...       ...     ...    ...
# 75  2159394289     False    html    htm
# 76  2159394317     False   image    ico
# 77  2159394297     False   image   webp
# 78  2159394305     False    font  woff2
# 79  2159394309     False    font  woff2
#
#                                                   url url_etld  status  \
# 0          http://cpqa.catchpoint.com/jp/191/v3.1.5/M      com     200
# 1                   https://www.bing.com/?form=MO0035      com     200
# 2                https://insertmedia.bing.office.net/      net     200
# 3                   https://www.bing.com/?FORM=UNKSBD      com     200
# 4      https://www.bing.com/search?q=it-n&form=MSDTR1      com     200
# ..                                                ...      ...     ...
# ...

# %%
fragmented_all[~fragmented_all['url'].isin(merged['url'])]
# Out:
# Empty DataFrame
# Columns: [requestId, firstReq, type, ext, url, url_etld, status, total_crawled_resources, total_crawled_domains, nel_max_age, nel_failure_fraction, nel_success_fraction, nel_include_subdomains, nel_report_to, total_crawled_resources_with_nel, rt_group, rt_collectors]
# Index: []

# %%
merged[~merged['url'].isin(fragmented_all['url'])]
# Out:
# Empty DataFrame
# Columns: [requestId, firstReq, type, ext, url, url_etld, status, total_crawled_resources, total_crawled_domains, nel_max_age, nel_failure_fraction, nel_success_fraction, nel_include_subdomains, nel_report_to, total_crawled_resources_with_nel, rt_group, rt_collectors]
# Index: []
